# %% [markdown]
# <a href="https://colab.research.google.com/github/EJVergz/AIDA-LEC/blob/main/58021_CS4DataExploration_TeyvatArchons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Dataset Exploration**
#
# **Teyvat Archons**
#
# $_{\text{©E.D.N Almaden, A.D Buenaventura, M.A Catinoy & E.J Vergara | 2022 }}$

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c7157bf4-708e-4704-a4aa-3b7abbb17e2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7157bf4-708e-4704-a4aa-3b7abbb17e2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import io
anime = pd.read_csv(io.BytesIO(uploaded['Anime.csv']))

# %%
anime_df.shape
# Out:
# (15278, 27)

# %%
anime_df = anime.copy()
anime_df
# Out:
#        animeID                               name            title_english  \
# 0            1                       Cowboy Bebop             Cowboy Bebop
# 1            5    Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2            6                             Trigun                   Trigun
# 3            7                 Witch Hunter Robin       Witch Hunter Robin
# 4            8                     Bouken Ou Beet   Beet the Vandel Buster
# ...        ...                                ...                      ...
# 15273    39195                           Beastars                      NaN
# 15274    39196            Mairimashita! Iruma-kun                      NaN
# 15275    39197             Karrimor Mountain Club   Karrimor Mountain Club
# 15276    39198                    Kanata no Astra                      NaN
# 15277    39199  Katsute Kami Datta Kemono-tachi e                      NaN
#
# ...

# %%
anime_df = anime.copy()
anime_df.head(10)
# Out:
#    animeID                             name            title_english  \
# 0        1                     Cowboy Bebop             Cowboy Bebop
# 1        5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2        6                           Trigun                   Trigun
# 3        7               Witch Hunter Robin       Witch Hunter Robin
# 4        8                   Bouken Ou Beet   Beet the Vandel Buster
# 5       16             Hachimitsu to Clover         Honey and Clover
# 6       17       Hungry Heart: Wild Striker                      NaN
# 7       18           Initial D Fourth Stage                      NaN
# 8       19                          Monster                  Monster
# 9       20                           Naruto                   Naruto
#
#              title_japanese                               title_synonyms  \
# 0                 カウボーイビバップ                                           []
# ...

# %%
anime_df = anime.copy()
anime_df.tail(3)
# Out:
#        animeID                               name           title_english  \
# 15275    39197             Karrimor Mountain Club  Karrimor Mountain Club
# 15276    39198                    Kanata no Astra                     NaN
# 15277    39199  Katsute Kami Datta Kemono-tachi e                     NaN
#
#                title_japanese                      title_synonyms  type  \
# 15275  Karrimor Mountain Club                                  []   ONA
# 15276                 彼方のアストラ             ['Astra Lost in Space']    TV
# 15277             かつて神だった獣たちへ  ['To the Abandoned Sacred Beasts']    TV
#
#          source  producers                                     genre  \
# 15275  Original         []            ['Adventure', 'Slice of Life']
# 15276     Manga         []  ['Action', 'Sci-Fi', 'Shounen', 'Space']
# 15277     Manga         []                    ['Fantasy', 'Shounen']
#
#            studio  ...   scored_by     rank  popularity  members  favorites  \
# ...

# %%
anime_df.dtypes
# Out:
# animeID              int64
#  name               object
#  title_english      object
#  title_japanese     object
#  title_synonyms     object
#  type               object
#  source             object
#  producers          object
#  genre              object
#  studio             object
#  episodes          float64
#  status             object
#  airing             object
#  aired              object
#  duration           object
#  rating             object
#  score             float64
#  scored_by         float64
#  rank              float64
#  popularity        float64
#  members           float64
#  favorites         float64
#  synopsis           object
#  background         object
#  premiered          object
#  broadcast          object
#  related            object
# dtype: object

# %%
anime_df[['animeID',' name',' title_english',' title_japanese',' title_synonyms',' type',' source',' producers',' genre',' studio']]
# Out:
#        animeID                               name            title_english  \
# 0            1                       Cowboy Bebop             Cowboy Bebop
# 1            5    Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2            6                             Trigun                   Trigun
# 3            7                 Witch Hunter Robin       Witch Hunter Robin
# 4            8                     Bouken Ou Beet   Beet the Vandel Buster
# ...        ...                                ...                      ...
# 15273    39195                           Beastars                      NaN
# 15274    39196            Mairimashita! Iruma-kun                      NaN
# 15275    39197             Karrimor Mountain Club   Karrimor Mountain Club
# 15276    39198                    Kanata no Astra                      NaN
# 15277    39199  Katsute Kami Datta Kemono-tachi e                      NaN
#
# ...

# %%
anime_df[['animeID',' name',' title_english',' title_japanese',' title_synonyms',' type',' source',' producers',' genre',' studio']]  .sort_values('animeID', ascending=False).head(10)
# Out:
#        animeID                               name           title_english  \
# 15277    39199  Katsute Kami Datta Kemono-tachi e                     NaN
# 15276    39198                    Kanata no Astra                     NaN
# 15275    39197             Karrimor Mountain Club  Karrimor Mountain Club
# 15274    39196            Mairimashita! Iruma-kun                     NaN
# 15273    39195                           Beastars                     NaN
# 15272    39194               Shin Chuuka Ichiban!                     NaN
# 15271    39192                 Xia Gu Zhong An Zu                     NaN
# 15270    39191                   Wan Jie Shen Zhu                     NaN
# 15269    39190                 Wang Zhe Wai Chuan                     NaN
# 15268    39189                 Te Ke Dong Ji Pian                     NaN
#
#                title_japanese                      title_synonyms     type  \
# 15277             かつて神だった獣たちへ  ['To the Abandoned Sacred Beasts']       TV
# ...

# %%
anime_df.describe()
# Out:
#             animeID      episodes         score     scored_by          rank  \
# count  15278.000000  14732.000000  14778.000000  1.527300e+04  13669.000000
# mean   19002.639416     11.726378      6.284508  1.210701e+04   6917.408004
# std    13706.437012     49.939231      1.073349  4.692942e+04   4003.814986
# min        1.000000      1.000000      1.000000  0.000000e+00      0.000000
# 25%     5209.250000      1.000000      5.600000  4.700000e+01   3448.000000
# 50%    18308.000000      2.000000      6.370000  4.700000e+02   6932.000000
# 75%    33025.750000     12.000000      7.050000  3.857000e+03  10416.000000
# max    39199.000000   3057.000000     10.000000  1.107955e+06  13838.000000
#
#          popularity       members      favorites
# count  15273.000000  1.527300e+04   15273.000000
# mean    7741.991292  2.450721e+04     329.457016
# std     4482.323035  8.223672e+04    2829.335394
# min        0.000000  0.000000e+00       0.000000
# ...

# %%
anime_df.columns
# Out:
# Index(['animeID', ' name', ' title_english', ' title_japanese',
#        ' title_synonyms', ' type', ' source', ' producers', ' genre',
#        ' studio', ' episodes', ' status', ' airing', ' aired', ' duration',
#        ' rating', ' score', ' scored_by', ' rank', ' popularity', ' members',
#        ' favorites', ' synopsis', ' background', ' premiered', ' broadcast',
#        ' related'],
#       dtype='object')

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15278 entries, 0 to 15277
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   animeID          15278 non-null  int64
#  1    name            15278 non-null  object
#  2    title_english   6122 non-null   object
#  3    title_japanese  15230 non-null  object
#  4    title_synonyms  15273 non-null  object
#  5    type            15273 non-null  object
#  6    source          15273 non-null  object
#  7    producers       15273 non-null  object
#  8    genre           15273 non-null  object
#  9    studio          15273 non-null  object
#  10   episodes        14732 non-null  float64
#  11   status          15273 non-null  object
#  12   airing          15273 non-null  object
#  13   aired           15273 non-null  object
#  14   duration        15273 non-null  object
#  15   rating          15273 non-null  object
# ...

# %%
anime_df.count()
# Out:
# Series([], dtype: int64)

# %%
print(anime_df.isnull().sum())
# Out:
# Series([], dtype: float64)

# %%
list_df = anime_df.groupby()
