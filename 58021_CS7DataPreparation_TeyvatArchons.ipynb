# %% [markdown]
# <a href="https://colab.research.google.com/github/EJVergz/AIDA-LEC/blob/main/58021_CS7DataPreparation_TeyvatArchons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Dataset Preparation**
#
# **Teyvat Archons**
#
# $_{\text{©E.D.N Almaden, A.D Buenaventura, M.A Catinoy & E.J Vergara | 2022 }}$

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-00b5d36a-ed1f-40c4-8077-c6aa7e63cd01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00b5d36a-ed1f-40c4-8077-c6aa7e63cd01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Flood.csv to Flood.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib
# %matplotlib inline

# %%
import io
flood = pd.read_csv(io.BytesIO(uploaded['Flood.csv']))

# %%
flood_df = flood.copy()
flood_df
# Out:
#             Timestamp                Permission to collect personal data  \
# 0   3/4/2022 12:48:45  Yes, I give consent to the collection of my pe...
# 1   3/4/2022 13:04:27  Yes, I give consent to the collection of my pe...
# 2   3/4/2022 13:06:23  Yes, I give consent to the collection of my pe...
# 3   3/4/2022 13:06:36  Yes, I give consent to the collection of my pe...
# 4   3/4/2022 13:12:59  Yes, I give consent to the collection of my pe...
# 5   3/4/2022 13:21:04  Yes, I give consent to the collection of my pe...
# 6   3/4/2022 13:30:19  Yes, I give consent to the collection of my pe...
# 7   3/4/2022 13:32:46  Yes, I give consent to the collection of my pe...
# 8   3/4/2022 13:35:06  Yes, I give consent to the collection of my pe...
# 9   3/4/2022 13:37:20  Yes, I give consent to the collection of my pe...
# 10  3/4/2022 13:38:20  Yes, I give consent to the collection of my pe...
# 11  3/4/2022 13:39:12  Yes, I give consent to the collection of my pe...
# ...

# %%
flood_df.shape
# Out:
# (29, 12)

# %%
flood_df.dtypes
# Out:
# Timestamp                                                           object
# Permission to collect personal data                                 object
# Permission to store personal data                                   object
# Permission to store personal data.1                                 object
# Full Name (FirstName MI. LastName)                                  object
# Age                                                                  int64
# Email Address/Contact Number                                        object
# Why should you study about flooding caused by structural floods?    object
# What may be causing the floods in your area?                        object
# What do you think the is most effective solution?                   object
# What effect does it have on you?                                    object
# What should you do if you suspect a flood?                          object
# dtype: object

# %%
flood_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 12 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Timestamp                                                         29 non-null     object
#  1   Permission to collect personal data                               29 non-null     object
#  2   Permission to store personal data                                 29 non-null     object
#  3   Permission to store personal data.1                               29 non-null     object
#  4   Full Name (FirstName MI. LastName)                                29 non-null     object
#  5   Age                                                               29 non-null     int64
#  6   Email Address/Contact Number                                      29 non-null     object
# ...

# %%
 def plotHorzBar(column):
  data = flood_df[column]
  count = {}
  for d in data:
    words = d.split(";")
    for w in words:
      if w in count.keys():
        count[w] = count[w] + 1
      else:
        count[w] = 1
  
  y_pos = np.arange(len(count.keys()))
  plt.barh(y_pos,count.values())
  plt.yticks(y_pos, count.keys())
  plt.show()

# %%
plotHorzBar("Why should you study about flooding caused by structural floods?")

# %%
plotHorzBar("What may be causing the floods in your area?")

# %%
plotHorzBar("What do you think the is most effective solution?")

# %%
plotHorzBar("What effect does it have on you?")

# %%
plotHorzBar("What should you do if you suspect a flood?")
